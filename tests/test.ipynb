# %%
import random
from datetime import date, timedelta

# %%
start = date.fromisoformat('2020-01-01') 
end = date.fromisoformat('2023-03-01') 
first_day = start + timedelta(random.randint(0, (end - start).days))
last_day = first_day + timedelta(random.randint(0, (end - first_day).days))

# %%
import pandas as pd
from cstf.update.utils import async_wrapper, get_current_df
df = pd.DataFrame(
        {
            "path_in_repo": [
                "pdb/protein/SARS-CoV-2/7abc",
                "pdb/protein/SARS-CoV-2/6xyz",
            ],
            "release_date": ["2022-01-01", "2021-06-01"],
        },
        index=["7abc", "6xyz"],
    )
df.loc["7abc", "release_date"]
# Out:
# '2022-01-01'

# %%
df["release_date"] = pd.to_datetime(df["release_date"])

# %%
ids = list(get_current_df(df, "2022-01-01", "2021-06-01").index)
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File ~/Documents/coronavirus_structural_task_force/.venv/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:1006, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1005 try:
# -> 1006     other = self._validate_comparison_value(other)
#    1007 except InvalidComparison:
#
# File ~/Documents/coronavirus_structural_task_force/.venv/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:565, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     564 elif not is_list_like(other):
# --> 565     raise InvalidComparison(other)
#     567 elif len(other) != len(self):
#
# InvalidComparison: 2022-01-01
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
first_day, last_day
# Out:
# (datetime.date(2021, 4, 24), datetime.date(2022, 9, 10))

# %%
def get_time(day: str = None, next_week: bool = False) -> date:
    """Returns last Wednesday's date."""
    day = date.fromisoformat(day) if day else date.today()
    offset = (day.weekday() - 2) % 7  # Wednesday = 2
    if offset == 0:
        return day
    return day - timedelta(offset) + next_week * timedelta(7)
